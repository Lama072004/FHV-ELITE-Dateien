# %% [markdown]
# # Abgabe Lineare Algebra - Übungen XX
#
# - **Name:** XXX YYYYY
# - **Studiengang:** ZZZ

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp

# %% [markdown]
# ## Aufgabe 1: XXX

# %% [markdown]
# ## Aufgabe 2: XXX

# %% [markdown]
# ## Aufgabe 3: XXX

# %% [markdown]
# ## Aufgabe 4: XXX

# %% [markdown]
# ## Aufgabe 5: XXX

# %% [markdown]
# ## Aufgabe 6: XXX
