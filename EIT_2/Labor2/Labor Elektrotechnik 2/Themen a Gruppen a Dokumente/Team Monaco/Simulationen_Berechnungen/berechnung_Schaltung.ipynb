# %%
import numpy as np

# %%
# Eingabe Werte BC337

U = 12              # Eingangsspannung DC
B = 250             # Muss anhand des Ic in der Grafik nachgesehen werden
Ic = 0.01           # Typisch für kleinverstärcker 5-20mA
m = 10               # 3 - 10 Üblich
Ube = 0.7           # Silizium = 0.7

# %%
def format_engineering(value, unit=''):
    prefixes = [
        (1e9, 'G'),   # Giga
        (1e6, 'M'),   # Mega
        (1e3, 'k'),   # Kilo
        (1, ''),      # keine Vorsilbe
        (1e-3, 'm'),  # Milli
        (1e-6, 'µ'),  # Mikro
        (1e-9, 'n'),  # Nano
        (1e-12, 'p')  # Piko
    ]
    
    for factor, prefix in prefixes:
        if abs(value) >= factor or factor == 1e-12:
            formatted_value = value / factor
            return f"{formatted_value:.3f} {prefix}{unit}"
    return f"{value} {unit}"  # Falls gar nichts passt


Rc = 5/Ic
Re = Rc/5
Ub0 = Ube + (Ic * Re)
Ib = Ic/B
Iq = m*Ib 
R2 = Ub0/(Iq-Ib)
R1 = (U-Ub0)/(Iq)
Uv = Rc/Re


print("Ic:              ",format_engineering(Ic, unit='A'))
print("Ib:              ",format_engineering(Ib, unit='A'))
print("Iq/IR2:          ",format_engineering(Iq, unit='A'))
print("Rc:              ",format_engineering(Rc, unit='Ω'))
print("Re:              ",format_engineering(Re, unit='Ω'))
print("R2:              ",format_engineering(R2, unit='Ω'))
print("R1:              ",format_engineering(R1, unit='Ω'))
print("U Verstäckung:   ", Uv)
# Out:
# Ic:               10.000 mA
# Ib:               40.000 µA
# Iq/IR2:           400.000 µA
# Rc:               500.000 Ω
# Re:               100.000 Ω
# R2:               4.722 kΩ
# R1:               25.750 kΩ
# U Verstäckung:    5.0

# %%
# Eingabe Werte 2N2222A

U = 12              # Eingangsspannung DC
B = 80             # Muss anhand des Ic in der Grafik nachgesehen werden, 75-100
Ic = 0.05           # Typisch für kleinverstärcker 5-20mA
m = 10               # 3 - 10 Üblich
Ube = 0.7           # Silizium = 0.7

# %%
#Berechnung und Ausgabe 2N2222A

def format_engineering(value, unit=''):
    prefixes = [
        (1e9, 'G'),   # Giga
        (1e6, 'M'),   # Mega
        (1e3, 'k'),   # Kilo
        (1, ''),      # keine Vorsilbe
        (1e-3, 'm'),  # Milli
        (1e-6, 'µ'),  # Mikro
        (1e-9, 'n'),  # Nano
        (1e-12, 'p')  # Piko
    ]
    
    for factor, prefix in prefixes:
        if abs(value) >= factor or factor == 1e-12:
            formatted_value = value / factor
            return f"{formatted_value:.3f} {prefix}{unit}"
    return f"{value} {unit}"  # Falls gar nichts passt


Rc = 5/Ic
Re = Rc/5
Ub0 = Ube + (Ic * Re)
Ib = Ic/B
Iq = m*Ib 
R2 = Ub0/(Iq-Ib)
R1 = (U-Ub0)/(Iq)
Uv = Rc/Re


print("Ic:              ",format_engineering(Ic, unit='A'))
print("Ib:              ",format_engineering(Ib, unit='A'))
print("Iq/IR2:          ",format_engineering(Iq, unit='A'))
print("Rc:              ",format_engineering(Rc, unit='Ω'))
print("Re:              ",format_engineering(Re, unit='Ω'))
print("R2:              ",format_engineering(R2, unit='Ω'))
print("R1:              ",format_engineering(R1, unit='Ω'))
print("U Verstäckung:   ", Uv)
# Out:
# Ic:               50.000 mA
# Ib:               625.000 µA
# Iq/IR2:           6.250 mA
# Rc:               100.000 Ω
# Re:               20.000 Ω
# R2:               302.222 Ω
# R1:               1.648 kΩ
# U Verstäckung:    5.0

# %%
# Eingabe Werte BC548B

U = 12              # Eingangsspannung DC
B = 200             # Muss anhand des Ic in der Grafik nachgesehen werden, 75-100
Ic = 0.05           # Typisch für kleinverstärcker 5-20mA
m = 10               # 3 - 10 Üblich
Ube = 0.7           # Silizium = 0.7

# %%
#Berechnung und Ausgabe BC548B, Mit Vd 5

def format_engineering(value, unit=''):
    prefixes = [
        (1e9, 'G'),   # Giga
        (1e6, 'M'),   # Mega
        (1e3, 'k'),   # Kilo
        (1, ''),      # keine Vorsilbe
        (1e-3, 'm'),  # Milli
        (1e-6, 'µ'),  # Mikro
        (1e-9, 'n'),  # Nano
        (1e-12, 'p')  # Piko
    ]
    
    for factor, prefix in prefixes:
        if abs(value) >= factor or factor == 1e-12:
            formatted_value = value / factor
            return f"{formatted_value:.3f} {prefix}{unit}"
    return f"{value} {unit}"  # Falls gar nichts passt


Rc = 5/Ic
Re = Rc/5
Ub0 = Ube + (Ic * Re)
Ib = Ic/B
Iq = m*Ib 
R2 = Ub0/(Iq-Ib)
R1 = (U-Ub0)/(Iq)
Uv = Rc/Re


print("Ic:              ",format_engineering(Ic, unit='A'))
print("Ib:              ",format_engineering(Ib, unit='A'))
print("Iq/IR2:          ",format_engineering(Iq, unit='A'))
print("Rc:              ",format_engineering(Rc, unit='Ω'))
print("Re:              ",format_engineering(Re, unit='Ω'))
print("R2:              ",format_engineering(R2, unit='Ω'))
print("R1:              ",format_engineering(R1, unit='Ω'))
print("U Verstäckung:   ", Uv)
# Out:
# Ic:               50.000 mA
# Ib:               250.000 µA
# Iq/IR2:           2.500 mA
# Rc:               100.000 Ω
# Re:               20.000 Ω
# R2:               755.556 Ω
# R1:               4.120 kΩ
# U Verstäckung:    5.0
